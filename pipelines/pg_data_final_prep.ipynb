# %%
import pandas as pd

df = pd.read_csv('../data/pg_data_1.csv')

df
# Out:
#      Unnamed: 0.1  Unnamed: 0                                      url  \
# 0               0           0  https://paulgraham.com/superlinear.html
# 1               1           1        https://paulgraham.com/alien.html
# 2               2           2  https://paulgraham.com/superangels.html
# 3               3           3        https://paulgraham.com/nerds.html
# 4               4           4          https://paulgraham.com/ffb.html
# ..            ...         ...                                      ...
# 217           217         217       https://paulgraham.com/unions.html
# 218           218         218      https://paulgraham.com/goodart.html
# 219           219         219        https://paulgraham.com/yahoo.html
# 220           220         220         https://paulgraham.com/lies.html
# 221           221         221     https://paulgraham.com/founders.html
#
#                                                content      type         name
# ...

# %%
filtered_df = df[df['content'].str.startswith('.')]

filtered_df
# Out:
#      Unnamed: 0.1  Unnamed: 0                                          url  \
# 2               2           2      https://paulgraham.com/superangels.html
# 5               5           5             https://paulgraham.com/boss.html
# 16             16          16          https://paulgraham.com/googles.html
# 18             18          18           https://paulgraham.com/wealth.html
# 20             20          20    https://paulgraham.com/determination.html
# 24             24          24        https://paulgraham.com/hiresfund.html
# 27             27          27            https://paulgraham.com/ideas.html
# 28             28          28           https://paulgraham.com/before.html
# 29             29          29         https://paulgraham.com/convince.html
# 31             31          31           https://paulgraham.com/bronze.html
# 34             34          34           https://paulgraham.com/growth.html
# ...

# %%
def remove_first_three_words(sentence):
    return ' '.join(sentence.split()[1:])

# Apply the function to clean 'content' in the filtered DataFrame
filtered_df['content'] = filtered_df['content'].apply(remove_first_three_words)
filtered_df
# Out:
# /var/folders/6j/7myxq8l12wz8s_qhqdqq6d4r0000gn/T/ipykernel_57948/3843185301.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['content'] = filtered_df['content'].apply(remove_first_three_words)
#      Unnamed: 0.1  Unnamed: 0                                          url  \
# 2               2           2      https://paulgraham.com/superangels.html
# 5               5           5             https://paulgraham.com/boss.html
# 16             16          16          https://paulgraham.com/googles.html
# 18             18          18           https://paulgraham.com/wealth.html
# 20             20          20    https://paulgraham.com/determination.html
# ...

# %%
df.update(filtered_df)

df
# Out:
#      Unnamed: 0.1  Unnamed: 0                                      url  \
# 0               0           0  https://paulgraham.com/superlinear.html
# 1               1           1        https://paulgraham.com/alien.html
# 2               2           2  https://paulgraham.com/superangels.html
# 3               3           3        https://paulgraham.com/nerds.html
# 4               4           4          https://paulgraham.com/ffb.html
# ..            ...         ...                                      ...
# 217           217         217       https://paulgraham.com/unions.html
# 218           218         218      https://paulgraham.com/goodart.html
# 219           219         219        https://paulgraham.com/yahoo.html
# 220           220         220         https://paulgraham.com/lies.html
# 221           221         221     https://paulgraham.com/founders.html
#
#                                                content      type         name
# ...

# %%
df['year'] = df['content'].str.extract('(\d{4})')

# Output the DataFrame to see the result
print(df)
# Out:
#      Unnamed: 0.1  Unnamed: 0                                      url  \
# 0               0           0  https://paulgraham.com/superlinear.html
# 1               1           1        https://paulgraham.com/alien.html
# 2               2           2  https://paulgraham.com/superangels.html
# 3               3           3        https://paulgraham.com/nerds.html
# 4               4           4          https://paulgraham.com/ffb.html
# ..            ...         ...                                      ...
# 217           217         217       https://paulgraham.com/unions.html
# 218           218         218      https://paulgraham.com/goodart.html
# 219           219         219        https://paulgraham.com/yahoo.html
# 220           220         220         https://paulgraham.com/lies.html
# 221           221         221     https://paulgraham.com/founders.html
#
#                                                content      type         name  \
# ...

# %%
# Convert 'year' content to integers and intentionally not manage errors, to generate NaNs
df['year'] = pd.to_numeric(df['year'], errors='coerce')  # Converts to float, NaN if conversion fails

# Display rows where 'year' is NaN
nan_rows = df[df['year'].isna()]

print("Rows with NaN in the 'year' field:")
nan_rows
df = df.dropna()

df
# Out:
# Rows with NaN in the 'year' field:
#      Unnamed: 0.1  Unnamed: 0                                      url  \
# 0               0           0  https://paulgraham.com/superlinear.html
# 1               1           1        https://paulgraham.com/alien.html
# 2               2           2  https://paulgraham.com/superangels.html
# 3               3           3        https://paulgraham.com/nerds.html
# 4               4           4          https://paulgraham.com/ffb.html
# ..            ...         ...                                      ...
# 217           217         217       https://paulgraham.com/unions.html
# 218           218         218      https://paulgraham.com/goodart.html
# 219           219         219        https://paulgraham.com/yahoo.html
# 220           220         220         https://paulgraham.com/lies.html
# 221           221         221     https://paulgraham.com/founders.html
#
# ...

# %%
# Convert 'year' content to integers and intentionally not manage errors, to generate NaNs
df['year'] = pd.to_numeric(df['year'], errors='coerce')  # Converts to float, NaN if conversion fails

# Replace NaN values in 'year' with 0
# df['year'].fillna(0, inplace=True)
df['year'] = df['year'].astype(int)
# Out:
# /var/folders/6j/7myxq8l12wz8s_qhqdqq6d4r0000gn/T/ipykernel_57948/2072690986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = pd.to_numeric(df['year'], errors='coerce')  # Converts to float, NaN if conversion fails
# /var/folders/6j/7myxq8l12wz8s_qhqdqq6d4r0000gn/T/ipykernel_57948/2072690986.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(int)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extracting year as string
# df['year'] = df['content'].str.split().str[1]

# Convert 'year' column to integer
df['year'] = df['year'].astype(int)

# Verify the conversion and data extraction

# Plotting
plt.figure(figsize=(20, 7))
min_year = df['year'].min()
max_year = df['year'].max()
plt.hist(df['year'], bins=range(min_year, max_year + 1), alpha=0.7, edgecolor='black')
plt.title('Frequency of Years')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.xticks(range(min_year, max_year + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /var/folders/6j/7myxq8l12wz8s_qhqdqq6d4r0000gn/T/ipykernel_57948/1439539213.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(int)

# %%
df.to_csv()
